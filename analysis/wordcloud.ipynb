# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
df = pd.read_csv('extracted_df.csv')

# %%
df
# Out:
#      Unnamed: 0                                   hash_id  \
# 0             0  0cb10f3c1267e41e7e5f871f88a0d4edb9058e0f
# 1             1  b7b95b014846f1c6c1d145bf367281d8e13fc6d9
# 2             2  048bd73b3c8ab68e0af473c752ada85e85c18469
# 3             3  5a93f5dbce64a78edfcbdfa6da64259de3f8849e
# 4             4  415585d23a5821737a4f4113c66d501f44c37c04
# ..          ...                                       ...
# 604         604  a8823ef0badb1a691c08bdfb25c86061acbe7b89
# 605         605  90c8a87698325f788c4b17098a2d1241b11f3ee8
# 606         606  b4512b1f3ed3f778a501ec84286c7d8830159da4
# 607         607  611904e5a7ccc00e895eb7b4a39df194cfedf74f
# 608         608  15254af9e4a04af0d72a077eb13cbbdce857edb4
#
#                                              job_title  \
# 0                        software engineer (ai verify)
# 1    senior ai engineer / ai engineer (innovation) ...
# 2    ai engineer (natural language processing)-ai s...
# ...

# %%
desc_text = df["job_description"].values
extracted_text = df["extracted"].values

# %%
desc_wordcloud = WordCloud().generate(str(desc_text))
extracted_wordcloud = WordCloud().generate(str(extracted_text))

# %%
plt.imshow(desc_wordcloud)
plt.axis('off')
plt.show()

# %%
plt.imshow(extracted_wordcloud)
plt.axis('off')
plt.show()
